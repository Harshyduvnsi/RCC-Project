# %%
#importing lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame
# %matplotlib inline

# %%
df=pd.read_csv("E:\ML RP\lung_cancer_examples.csv")

# %%
print(df)
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
df
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
df=df.rename(columns = {'Name':'FirstName','Surname':'LastName'})

# %%
df
# Out:
#       FirstName     LastName  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
df = df.drop(['FirstName','LastName'], axis =1)

# %%
df
# Out:
#     Age  Smokes  AreaQ  Alkhol  Result
# 0    35       3      5       4       1
# 1    27      20      2       5       1
# 2    30       0      5       2       0
# 3    28       0      8       1       0
# 4    68       4      5       6       1
# 5    34       0     10       0       0
# 6    58      15     10       0       0
# 7    22      12      5       2       0
# 8    45       2      6       0       0
# 9    52      18      4       5       1
# 10   33       4      8       0       0
# 11   18      10      6       3       0
# 12   25       2      5       1       0
# 13   28      20      2       8       1
# 14   34      25      4       8       1
# 15   39      18      8       1       0
# 16   42      22      3       5       1
# 17   19      12      8       0       0
# 18   62       5      4       3       1
# 19   73      10      7       6       1
# 20   55      15      1       3       1
# 21   33       8      8       1       0
# 22   22      20      6       2       0
# ...

# %%
df.shape
# Out:
# (59, 5)

# %%
df.columns
# Out:
# Index(['Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'], dtype='object')

# %%
df.head()
# Out:
#    Age  Smokes  AreaQ  Alkhol  Result
# 0   35       3      5       4       1
# 1   27      20      2       5       1
# 2   30       0      5       2       0
# 3   28       0      8       1       0
# 4   68       4      5       6       1

# %%
df.tail()
# Out:
#     Age  Smokes  AreaQ  Alkhol  Result
# 54   26      13      6       1       0
# 55   77      20      5       4       1
# 56   75      15      3       5       1
# 57   43      30      3       8       1
# 58   51      25      9       0       0

# %%
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     59 non-null     int64
#  1   Smokes  59 non-null     int64
#  2   AreaQ   59 non-null     int64
#  3   Alkhol  59 non-null     int64
#  4   Result  59 non-null     int64
# dtypes: int64(5)
# memory usage: 2.4 KB

# %%
sns.catplot(x='Result',data=df,kind='count')

# %%
plt.boxplot(df.Age)
Q1 = df.Age.quantile(0.25)
Q3 = df.Age.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Age >= Q1 - 1.5*IQR) & (df.Age <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.Smokes)
Q1 = df.Smokes.quantile(0.25)
Q3 = df.Smokes.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Smokes >= Q1 - 1.5*IQR) & (df.Smokes <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.AreaQ)
Q1 = df.AreaQ.quantile(0.25)
Q3 = df.AreaQ.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.AreaQ >= Q1 - 1.5*IQR) & (df.AreaQ <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.Alkhol)
Q1 = df.Alkhol.quantile(0.25)
Q3 = df.Alkhol.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Alkhol >= Q1 - 1.5*IQR) & (df.Alkhol <= Q3 + 1.5*IQR)]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),color = "k", annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#              Age    Smokes     AreaQ    Alkhol    Result
# Age     1.000000  0.053665 -0.268957  0.318621  0.637726
# Smokes  0.053665  1.000000 -0.353295  0.469915  0.373444
# AreaQ  -0.268957 -0.353295  1.000000 -0.714412 -0.746621
# Alkhol  0.318621  0.469915 -0.714412  1.000000  0.810439
# Result  0.637726  0.373444 -0.746621  0.810439  1.000000

# %%
df.hist(bins=20,figsize=(11,11))
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
Norm_scale = ['Age','Smokes','AreaQ','Alkhol']

# %%
df[Norm_scale] = scaler.fit_transform(df[Norm_scale])

# %%
df
# Out:
#          Age    Smokes     AreaQ  Alkhol  Result
# 0   0.288136  0.088235  0.444444   0.500       1
# 1   0.152542  0.588235  0.111111   0.625       1
# 2   0.203390  0.000000  0.444444   0.250       0
# 3   0.169492  0.000000  0.777778   0.125       0
# 4   0.847458  0.117647  0.444444   0.750       1
# 5   0.271186  0.000000  1.000000   0.000       0
# 6   0.677966  0.441176  1.000000   0.000       0
# 7   0.067797  0.352941  0.444444   0.250       0
# 8   0.457627  0.058824  0.555556   0.000       0
# 9   0.576271  0.529412  0.333333   0.625       1
# 10  0.254237  0.117647  0.777778   0.000       0
# 11  0.000000  0.294118  0.555556   0.375       0
# 12  0.118644  0.058824  0.444444   0.125       0
# 13  0.169492  0.588235  0.111111   1.000       1
# 14  0.271186  0.735294  0.333333   1.000       1
# 15  0.355932  0.529412  0.777778   0.125       0
# 16  0.406780  0.647059  0.222222   0.625       1
# 17  0.016949  0.352941  0.777778   0.000       0
# ...

# %% [markdown]
# CLASSIFICATION.

# %% [markdown]
# RFC

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
Y = df['Result']
X = df[['Age','Smokes','AreaQ','Alkhol']]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn import metrics

# %%
X_train, X_test , y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
pip install imblearn
# Out:
# ...
#
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(k_neighbors=4)
X,Y= sm.fit_resample(X,Y)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_pred = rfc.predict(X_test)

# %%
print("Accuracy : %.2f%%" % (accuracy_score(rfc_pred,y_test)*100.0))
# Out:
# Accuracy : 91.67%

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Y = df['Result']
X = df[['Age','Smokes','AreaQ','Alkhol']]

# %%
sm = SMOTE(k_neighbors=4)
X,Y= sm.fit_resample(X,Y)

# %%
X_train, X_test , y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn_pred = knn.predict(X_test)

# %%
print("Accuracy",metrics.accuracy_score(y_test, knn_pred)*100)
# Out:
# Accuracy 84.61538461538461

# %% [markdown]
# DCT

# %%
from sklearn import preprocessing

# %%
from sklearn import tree

# %%
Y = df['Result']
X = df[['Age','Smokes','AreaQ','Alkhol']]

# %%
sm = SMOTE(k_neighbors=4)
X,Y= sm.fit_resample(X,Y)

# %%
X_train, X_test , y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
dt = tree.DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(X_test)

# %%
print("Accuracy",metrics.accuracy_score(y_test, dt_pred)*100)
# Out:
# Accuracy 100.0

# %% [markdown]
# PREDICTION

# %%
r,c = 2,4
l1 = [[0 for x in range (c)] for y in range(r)]

Age = float(input("Age(18-77) :"))
l1[0][0]=Age
l1[1][0]=Age

Smokes = float(input("Smokes(0-34) :"))
l1[0][1]=Smokes
l1[1][1]=Smokes

AreaQ = float(input("AreaQ(1-10) :"))
l1[0][2]=AreaQ
l1[1][2]=AreaQ

Alkhol = float(input("Alkhol(0-8) :"))
l1[0][3]=Alkhol
l1[1][3]=Alkhol
# Out:
# Age(18-77) :23
# Smokes(0-34) :12
# AreaQ(1-10) :7
# Alkhol(0-8) :5

# %%
dt_pred = dt.predict(l1)
print('Result')
print(float(dt_pred[0]))
# Out:
# Result
# 1.0

# %% [markdown]
# END
